# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = np.array([24,33,2,4,7,9,11,19,25,24,33,15,24])

df = pd.DataFrame()
df["age"] = a
df
# Out:
#     age
# 0    24
# 1    33
# 2     2
# 3     4
# 4     7
# 5     9
# 6    11
# 7    19
# 8    25
# 9    24
# 10   33
# 11   15
# 12   24

# %%
df["age"].mean()
# Out:
# 17.166666666666668

# %%
df["age"].median()  # we need to sort the values before getting median.
# Out:
# 17.0

# %%
print(a)
# Out:
# [24 33  2  4  7  9 11 19 25 24 33 15]

# %%
df["age"].mode()
# Out:
# 0    24
# Name: age, dtype: int64

# %%
df = pd.DataFrame({"Kohli" : [34,28,32,38,40,36],"Rohith" : [80,25,0,40,4,13]})
df
# Out:
#    Kohli  Rohith
# 0     34      80
# 1     28      25
# 2     32       0
# 3     38      40
# 4     40       4
# 5     36      13

# %%
print(df["Rohith"].var())
# Out:
# 887.2
